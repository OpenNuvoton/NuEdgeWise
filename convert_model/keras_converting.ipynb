# %% [markdown]
# # Converting Keras/Tensorflow Model to tflite model
# - This Demo showing how to converting the model into a tflite format which Nuvoton MCU can support
# -  More detail and reference from here: [post_training_quantization](https://ai.google.dev/edge/litert/models/post_training_quantization?hl=zh-cn)

# %% [markdown]
# ## 1. Load your model
# - Here we use mobilenetv2 model of image classification task as an example.

# %%
import tensorflow as tf
import numpy as np
import os
import sys
import logging

IMG_SHAPE = (160, 160, 3)
custom_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                                include_top=True,
                                                weights='imagenet',
                                                alpha=0.35)

# %% [markdown]
# - Another example: keras3 model
# - Need to install keras3

# %%
import keras

custom_model_path = 'example_model.keras'
keras_model = tf.keras.models.load_model(custom_model_path)

# %% [markdown]
# ## 2. Create the representative dataset
# - This is needed if you wnat to convert to int8 full quantitation model (PTQ method).
# - Below is the example random dataset, you need to create your representative dataset follow the same inputs format of model.

# %%
def representative_dataset():
    for _ in range(100):
      data = np.random.rand(1, 160, 160, 3)
      yield [data.astype(np.float32)]

# %% [markdown]
# ## 3. Converting to tflite
# - We show 3 differents tflite models, No quantization, Full integer quantization, and INT8 Full integer quantization.
# - All models can support CPU device.
# - For NPU device like M55M1, it only supports INT8 Full integer quantization and need vela compiler.

# %% [markdown]
# ### No Quantization

# %%
MODEL_NAME = 'MNV2'
tf.get_logger().setLevel(logging.ERROR)

converter = tf.lite.TFLiteConverter.from_keras_model(custom_model)
tflite_model = converter.convert()
output_location = os.path.join('model', (MODEL_NAME + r'.tflite'))
with open(output_location, 'wb') as f:
    f.write(tflite_model)
    print("The tflite output location: {}".format(output_location))
# Out:
# Saved artifact at 'C:\Users\cychen38\AppData\Local\Temp\tmplu7wb4n6'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 160, 160, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 1000), dtype=tf.float32, name=None)
# Captures:
#   2853761443344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761635552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761637664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761630976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761633264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761645056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761644000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761640480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761637312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761645232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761635376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761718704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761719760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761715888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761718528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761640832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761723456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761725920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761722048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761724688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761722400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761814192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761816832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761812784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761814720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761822992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761821936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761824400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761810848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761823168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761812432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761911616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761631328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761912144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761911792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761444224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761919536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761920240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761915840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761918128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761923232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761976096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761974688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761924288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761976272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761444928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761982080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761984544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761980672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761983312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761988768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778686192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778686368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761990352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778687952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761987536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778694112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778696576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778692704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778695344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778701328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778693056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778694992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778699040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778701152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778700624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778740624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778743264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778739216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778741152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778749424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778748368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778750832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778737280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778749600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761987712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778888608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778889664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778885792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778888432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778895648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778894592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778897232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778886144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778895120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778891248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778969472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778970528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778966656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778969296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778737456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778975632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778978096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778974224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778976864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778974576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779066544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779069184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779065136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779067072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779075344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779074288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779076752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779063200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779075520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779064784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779147584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779145648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779148112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779147760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779154624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779153568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779156208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779144944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779154096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779159200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779212064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779210656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779160256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779212240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779063376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779218224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779220688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779216816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779219456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779223504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779223152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779223328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779224560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779293456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779222272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779300496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779301552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779297680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779300320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779150400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779298032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853
: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779718736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779718912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779720848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779633808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779727008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779729472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779725600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779728240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779721376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779801712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779800304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779733520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779801888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779808752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779807696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779810336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779802064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779808224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779813328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779806640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779812096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779814384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779883104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779633984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779890144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779891200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779887328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779889968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779895424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779895072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779895248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779896480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779998144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779894192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780005184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780006240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780002368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780005008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779804528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780009936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780012400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780008528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780011168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780008880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780132208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780134848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780130800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780132736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780141008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780139952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780142416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780128864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780141184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779894368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780247424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780248480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780244608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780247248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780254464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780253408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780256048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780244960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780253936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780250064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780279136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780276672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780275792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780279312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780129040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780285296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780287760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780283888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780286528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780290576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780391008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780390656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780393120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780392768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780289344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780398928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780401392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780397520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780400160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780392240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780397872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780401920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780404208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780472928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780476800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780477680: TensorSpec(shape=(), dtype=tf.resource, name=None)
# C:\ProgramData\miniforge3\envs\tf_new\lib\site-packages\tensorflow\lite\python\convert.py:991: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# The tflite output location: model\MNV2_fullquant.tflite

# %% [markdown]
# ### Int8 Full integer quantization
# - including input and output int8. For ARM NPU device.

# %%
MODEL_NAME = 'MNV2'
converter = tf.lite.TFLiteConverter.from_keras_model(custom_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8, tf.lite.OpsSet.TFLITE_BUILTINS]
converter.representative_dataset = representative_dataset
converter.inference_input_type = tf.int8  # or tf.uint8
converter.inference_output_type = tf.int8  # or tf.uint8
tflite_model = converter.convert()
output_location = os.path.join('model', (MODEL_NAME + r'_int8quant.tflite'))
with open(output_location, 'wb') as f:
    f.write(tflite_model)
    print("The tflite output location: {}".format(output_location))
# Out:
# Saved artifact at 'C:\Users\cychen38\AppData\Local\Temp\tmp1h6aw8rh'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 160, 160, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 1000), dtype=tf.float32, name=None)
# Captures:
#   2853761443344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761635552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761637664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761630976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761633264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761645056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761644000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761640480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761637312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761645232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761635376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761718704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761719760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761715888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761718528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761640832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761723456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761725920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761722048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761724688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761722400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761814192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761816832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761812784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761814720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761822992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761821936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761824400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761810848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761823168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761812432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761911616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761631328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761912144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761911792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761444224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761919536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761920240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761915840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761918128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761923232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761976096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761974688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761924288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761976272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761444928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761982080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761984544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761980672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761983312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761988768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778686192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778686368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761990352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778687952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761987536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778694112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778696576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778692704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778695344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778701328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778693056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778694992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778699040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778701152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778700624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778740624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778743264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778739216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778741152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778749424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778748368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778750832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778737280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778749600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853761987712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778888608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778889664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778885792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778888432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778895648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778894592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778897232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778886144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778895120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778891248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778969472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778970528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778966656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778969296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778737456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778975632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778978096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778974224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778976864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853778974576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779066544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779069184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779065136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779067072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779075344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779074288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779076752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779063200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779075520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779064784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779147584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779145648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779148112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779147760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779154624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779153568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779156208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779144944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779154096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779159200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779212064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779210656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779160256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779212240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779063376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779218224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779220688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779216816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779219456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779223504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779223152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779223328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779224560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779293456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779222272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779300496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779301552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779297680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779300320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779150400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779298032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779303136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779304896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779306480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779306832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779428928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779431568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779427520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779429456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779437728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779436672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779439136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779425584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779437904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779222448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779544144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779545200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779541328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779543968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779551184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779550128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779552768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779541680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779550656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779546784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779625008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779626064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779622192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779624832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779425760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779629760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779632224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779628352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779630992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779635040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779719088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779718736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779718912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779720848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779633808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779727008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779729472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779725600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779728240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779721376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779801712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779800304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779733520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779801888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779808752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779807696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779810336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779802064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779808224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779813328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779806640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779812096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779814384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779883104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779633984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779890144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779891200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779887328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779889968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779895424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779895072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779895248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779896480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779998144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779894192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780005184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780006240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780002368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780005008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779804528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780009936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780012400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780008528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780011168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780008880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780132208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780134848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780130800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780132736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780141008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780139952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780142416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780128864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780141184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853779894368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780247424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780248480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780244608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780247248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780254464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780253408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780256048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780244960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780253936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780250064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780279136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780276672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780275792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780279312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780129040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780285296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780287760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780283888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780286528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780290576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780391008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780390656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780393120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780392768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780289344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780398928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780401392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780397520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780400160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780392240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780397872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780401920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780404208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780472928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780476800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2853780477680: TensorSpec(shape=(), dtype=tf.resource, name=None)
# C:\ProgramData\miniforge3\envs\tf_new\lib\site-packages\tensorflow\lite\python\convert.py:991: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# The tflite output location: model\MNV2_int8quant.tflite

# %% [markdown]
# # 4. Change the tflite model to C binary format
# - First we convert (A.) No Quantization & (B.) Full integer quantization model to support cortex-M CPU
# - Second we convert (C.) Int8 Full integer quantization model to support NPU (with ARM vela compiler)

# %% [markdown]
# ### (A.) No Quantization

# %%
TFLITE_PATH = os.path.join('model', (MODEL_NAME + r'.tflite'))
OUT_FILE = os.path.join('model', (MODEL_NAME + r'_tflite.cc'))

! python tflite_to_tflu_para.py --tflite_path $TFLITE_PATH --output_path $OUT_FILE

# %% [markdown]
# ### (B.) Full integer quantization

# %%
TFLITE_PATH = os.path.join('model', (MODEL_NAME + r'_fullquant.tflite'))
OUT_FILE = os.path.join('model', (MODEL_NAME + r'_fullquant_tflite.cc'))

! python tflite_to_tflu_para.py --tflite_path $TFLITE_PATH --output_path $OUT_FILE

# %% [markdown]
# #### 1. Move the tflite model to your C++ project
# - Tflite model C++ file can be replaced in model or generated directory.
# - Please check the detail in [OpenNuvoton/ML_M460_SampleCode](https://github.com/OpenNuvoton/ML_M460_SampleCode/tree/master)

# %% [markdown]
# ### (C.) Int8 Full integer quantization + vela compiler for NPU device

# %% [markdown]
# #### 1. Edit `vela/variables.bat`

# %% [markdown]
# - Set `MODEL_SRC_DIR` to the directory saves the model
#   - Here is `..\model`
# - Update `MODEL_SRC_FILE` to your int8 full interger quantization tflite model
#   - For example: `MODEL_SRC_FILE=MNV2_int8quant.tflite`

# %% [markdown]
# #### 2. Execute `vela/gen_model_cpp.bat`

# %% [markdown]
# - The output vela tflite & vela tflite C++ files are in `vela/generated`

# %% [markdown]
# #### 3. Move the tflite model to your C++ project

# %% [markdown]
# - Vela tflite model file can loaded in SD card.
# - Vela tflite model C++ file can be replaced in model or generated directory.
# - Please check the detail in [OpenNuvoton/ML_M55M1_SampleCode](https://github.com/OpenNuvoton/ML_M55M1_SampleCode/tree/master)
